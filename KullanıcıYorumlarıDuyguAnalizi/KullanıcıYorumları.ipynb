# %% [markdown]
# # BERT

# %%
! pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.31.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.14.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.3.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers) (4.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)

# %%
import torch
from transformers import AutoModel, AutoTokenizer
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import pandas as pd

# %%
tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")
bert = AutoModel.from_pretrained("dbmdz/bert-base-turkish-cased")

# %%
df = pd.read_csv('/content/drive/MyDrive/Miuul-NLP/magaza_yorumlari_duygu_analizi.csv', encoding="utf-16")
df = df.dropna()

# %%
df.head()
# Out:
#                                                Görüş     Durum
# 0  ses kalitesi ve ergonomisi rezalet, sony olduğ...   Olumsuz
# 1                         hizli teslimat tesekkürler  Tarafsız
# 2  ses olayı süper....gece çalıştır sıkıntı yok.....    Olumlu
# 3  geldi bigün kullandık hemen bozoldu hiçtavsiye...   Olumsuz
# 4  Kulaklığın sesi kaliteli falan değil. Aleti öv...   Olumsuz

# %%
def get_embeddings(text):

  # Tokenize the text
  tokens = tokenizer(text, return_tensors='pt', padding=True, truncation=True, max_length=512)

  with torch.no_grad():
      # Get the output from BERT
      outputs = bert(**tokens)

  # The output will be a tuple containing various components, but the embeddings will be the first element
  embeddings = outputs.last_hidden_state

  return list(embeddings[0][0].cpu().numpy())

# %%
get_embeddings("Harika bir gün!")
# Out:
# [0.94014996,
#  -0.15150273,
#  -0.11292617,
#  -0.500578,
#  1.8512871,
#  0.9194206,
#  0.24045298,
#  0.58969253,
#  0.2364179,
#  0.21101466,
#  -0.099310435,
#  -1.630967,
#  -0.7358298,
#  0.47735637,
#  -1.5192066,
#  -0.021660913,
#  0.24132323,
#  1.3695418,
#  -1.7254006,
#  0.50128084,
#  -0.15161066,
#  0.37898135,
#  -1.0392346,
#  1.3495327,
#  -0.5798781,
#  -1.7850611,
#  -1.9805862,
#  -1.0556116,
#  0.68036264,
#  1.716354,
#  0.2072346,
#  1.136086,
#  0.07009561,
#  -0.5709068,
#  0.11128219,
#  -0.71428174,
#  0.53104484,
#  -1.172731,
#  -0.6565185,
#  0.6519561,
#  -0.32488015,
#  -0.07250288,
#  0.49978864,
#  -2.1062849,
#  -0.36744374,
#  0.21123058,
#  0.5081913,
#  -1.5649892,
#  -0.9894364,
#  -1.4741789,
#  1.0882179,
#  -0.78842413,
#  2.027399,
#  -0.92301583,
#  -0.5602822,
#  0.0910885,
#  -2.0187075,
#  -1.0279602,
#  -0.6576938,
#  2.2609138,
#  1.6792718,
#  -0.060546566,
#  -0.20890845,
#  -0.28595126,
#  -0.38888207,
#  0.9384547,
#  0.76370263,
#  -1.647727,
#  0.503553,
#  1.5720172,
#  0.38632405,
#  -1.2101849,
#  0.82727915,
#  -0.35365245,
#  -1.9714226,
#  0.6920349,
#  0.17050055,
#  -1.5653778,
#  0.66010773,
#  0.9658803,
#  -0.77816665,
#  0.43337047,
#  0.3084483,
#  -0.2004212,
#  0.13362749,
#  0.7054653,
#  1.3269161,
#  0.8495375,
#  -0.9053066,
#  -1.1481457,
#  -0.011710408,
#  -2.8132648,
#  -0.18138178,
#  1.3960606,
#  1.4078069,
#  -0.24297132,
#  -0.6035545,
#  1.675134,
#  1.3802594,
#  0.00603747,
#  0.9354401,
#  -0.012056429,
#  0.9981899,
#  -0.7517181,
#  -0.281635,
#  1.2396204,
#  -0.99561733,
#  -0.7238687,
#  0.59057456,
#  -0.6662627,
#  -0.2807254,
#  -0.8206576,
#  -0.94155043,
#  -0.48425642,
#  2.1475046,
#  0.18903682,
#  0.39338556,
#  0.103084676,
#  -1.3914777,
#  0.40937084,
#  -1.8290826,
#  0.27813894,
#  -0.47496623,
#  0.19712372,
#  0.1503222,
#  0.072951436,
#  0.4031038,
#  0.44767773,
#  -0.38406223,
#  -0.70305866,
#  0.024454871,
#  -0.103934176,
#  0.99461305,
#  -0.33035642,
#  -1.1451056,
#  -0.18339868,
#  -1.3685845,
#  -0.89974385,
#  -0.7373038,
#  -0.37792128,
#  0.67195433,
#  0.2945333,
#  0.48010853,
#  0.62432945,
#  1.568144,
#  0.24657206,
#  1.8097656,
#  0.8865949]

# %%
X = df.iloc[:,0]
y = df.iloc[:,1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
y_train
# Out:
# 8977       Olumlu
# 2054     Tarafsız
# 11001     Olumsuz
# 10532     Olumsuz
# 2362      Olumsuz
#            ...
# 11287     Olumsuz
# 5192       Olumlu
# 5391       Olumlu
# 860       Olumsuz
# 7273       Olumlu
# Name: Durum, Length: 7655, dtype: object

# %%
mapping = {'Olumsuz': 0, 'Tarafsız': 1, 'Olumlu': 2}

# %%
X_train_final = []
y_train_final = []

for text, label in zip(X_train, y_train):
  X_train_final.append(get_embeddings(text))
  y_train_final.append(mapping[label])

# %%
X_test_final = []
y_test_final = []

for text, label in zip(X_test, y_test):
  X_test_final.append(get_embeddings(text))
  y_test_final.append(mapping[label])

# %%
model = MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=1000, activation='tanh', solver='adam', alpha=1e-5, learning_rate='constant',
                      verbose=1, early_stopping=True)
model.fit(X_train_final, y_train_final)
y_true, y_pred = y_test_final, model.predict(X_test_final)
print(classification_report(y_true, y_pred))
# Out:
# Iteration 1, loss = 1.06351458
# Validation score: 0.539164
# Iteration 2, loss = 0.89620879
# Validation score: 0.613577
# Iteration 3, loss = 0.83275517
# Validation score: 0.659269
# Iteration 4, loss = 0.78448619
# Validation score: 0.627937
# Iteration 5, loss = 0.76050133
# Validation score: 0.678851
# Iteration 6, loss = 0.74235810
# Validation score: 0.671018
# Iteration 7, loss = 0.72626629
# Validation score: 0.654047
# Iteration 8, loss = 0.72044637
# Validation score: 0.701044
# Iteration 9, loss = 0.69358593
# Validation score: 0.655352
# Iteration 10, loss = 0.68569588
# Validation score: 0.686684
# Iteration 11, loss = 0.71221940
# Validation score: 0.695822
# Iteration 12, loss = 0.68943563
# Validation score: 0.691906
# Iteration 13, loss = 0.65847517
# Validation score: 0.699739
# Iteration 14, loss = 0.67266415
# Validation score: 0.691906
# Iteration 15, loss = 0.64907558
# Validation score: 0.682768
# Iteration 16, loss = 0.64510272
# Validation score: 0.703655
# Iteration 17, loss = 0.63225938
# Validation score: 0.707572
# Iteration 18, loss = 0.63154014
# Validation score: 0.710183
# Iteration 19, loss = 0.64549479
# Validation score: 0.691906
# Iteration 20, loss = 0.62263502
# Validation score: 0.711488
# Iteration 21, loss = 0.63997809
# Validation score: 0.682768
# Iteration 22, loss = 0.61861614
# Validation score: 0.660574
# Iteration 23, loss = 0.61749666
# Validation score: 0.706266
# Iteration 24, loss = 0.59770280
# Validation score: 0.694517
# Iteration 25, loss = 0.60430614
# Validation score: 0.711488
# Iteration 26, loss = 0.59349128
# Validation score: 0.719321
# Iteration 27, loss = 0.58831161
# Validation score: 0.703655
# Iteration 28, loss = 0.61232775
# Validation score: 0.721932
# Iteration 29, loss = 0.57103882
# Validation score: 0.711488
# Iteration 30, loss = 0.57803047
# Validation score: 0.720627
# Iteration 31, loss = 0.57368823
# Validation score: 0.678851
# Iteration 32, loss = 0.56641723
# Validation score: 0.706266
# Iteration 33, loss = 0.55999804
# Validation score: 0.714099
# Iteration 34, loss = 0.55837691
# Validation score: 0.693211
# Iteration 35, loss = 0.55412967
# Validation score: 0.708877
# Iteration 36, loss = 0.53660809
# Validation score: 0.702350
# Iteration 37, loss = 0.54637911
# Validation score: 0.725849
# Iteration 38, loss = 0.53160156
# Validation score: 0.723238
# Iteration 39, loss = 0.54157103
# Validation score: 0.704961
# Iteration 40, loss = 0.56544718
# Validation score: 0.687990
# Iteration 41, loss = 0.54680196
# Validation score: 0.691906
# Iteration 42, loss = 0.53884978
# Validation score: 0.720627
# Iteration 43, loss = 0.51512324
# Validation score: 0.702350
# Iteration 44, loss = 0.51489046
# Validation score: 0.708877
# Iteration 45, loss = 0.53792365
# Validation score: 0.697128
# Iteration 46, loss = 0.51470545
# Validation score: 0.732376
# Iteration 47, loss = 0.52289777
# Validation score: 0.727154
# Iteration 48, loss = 0.50740991
# Validation score: 0.712794
# Iteration 49, loss = 0.49644043
# Validation score: 0.702350
# Iteration 50, loss = 0.49850302
# Validation score: 0.676240
# Iteration 51, loss = 0.52043805
# Validation score: 0.706266
# Iteration 52, loss = 0.49976776
# Validation score: 0.715405
# Iteration 53, loss = 0.50875757
# Validation score: 0.714099
# Iteration 54, loss = 0.48621614
# Validation score: 0.698433
# Iteration 55, loss = 0.47395729
# Validation score: 0.714099
# Iteration 56, loss = 0.48971249
# Validation score: 0.707572
# Iteration 57, loss = 0.50604758
# Validation score: 0.725849
# Validation score did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
#               precision    recall  f1-score   support
#
#            0       0.69      0.80      0.74      1394
#            1       0.48      0.37      0.42       966
#            2       0.78      0.78      0.78      1411
#
#     accuracy                           0.68      3771
#    macro avg       0.65      0.65      0.64      3771
# weighted avg       0.67      0.68      0.67      3771

# %%
len(X_train_final[0])
# Out:
# 768

# %%
len(X_test_final[0])
# Out:
# 768

# %%
model.predict([get_embeddings("Puan kırmamın sebebi trendyol express kuryelerinin sorumsuzluğu yoksa ürün sorunsuz")])
# Out:
# array([1])
